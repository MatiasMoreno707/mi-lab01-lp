# %% [markdown]
# <a href="https://colab.research.google.com/github/MatiasMoreno707/mi-lab01-lp/blob/develop/lab01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. En esta ocasión, pondrá en práctica lo visto en la clase anterior. Para ello, debe extraer una base
# de datos del repositorio UCI Machine Learning Repository y otra de Kaggle (no olvide tener su
# cuenta creada). Luego, utilizando funciones o métodos de Python y agregando comentarios en
# cada parte, haga lo siguiente:

# %% [markdown]
# a. Lea cada base de datos y almacénela en un data frame indicando la cantidad de registros y
# atributos.

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/sample_data/california_housing_test.csv')
df.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
# 5    -119.56     36.51                37.0       1018.0           213.0
# 6    -121.43     38.63                43.0       1009.0           225.0
# 7    -120.65     35.48                19.0       2310.0           471.0
# 8    -122.84     38.40                15.0       3080.0           617.0
# 9    -118.02     34.08                31.0       2402.0           632.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# ...

# %%
df.shape
# Out:
# (3000, 9)

# %% [markdown]
# b. Determine la cantidad de variables numéricas y no numéricas. Además, indique si existen
# valores perdidos.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
#memoria usada por variable en bytes
df.memory_usage()
# Out:
# Index                   132
# longitude             24000
# latitude              24000
# housing_median_age    24000
# total_rooms           24000
# total_bedrooms        24000
# population            24000
# households            24000
# median_income         24000
# median_house_value    24000
# dtype: int64

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %% [markdown]
# c. Calcule estadísticos descriptivos para las variables numéricas (medidas de tendencia central,
# medidas de dispersión, valor máximo, valor mínimo, entre otras).

# %%
df.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %%
#mediana
df.median()
# Out:
# longitude               -118.48500
# latitude                  34.27000
# housing_median_age        29.00000
# total_rooms             2106.00000
# total_bedrooms           437.00000
# population              1155.00000
# households               409.50000
# median_income              3.48715
# median_house_value    177650.00000
# dtype: float64

# %%
df.max()
# Out:
# longitude               -114.4900
# latitude                  41.9200
# housing_median_age        52.0000
# total_rooms            30450.0000
# total_bedrooms          5419.0000
# population             11935.0000
# households              4930.0000
# median_income             15.0001
# median_house_value    500001.0000
# dtype: float64
